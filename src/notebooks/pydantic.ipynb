# %%
#A decorator takes a function as input and returns a new function that adds some kind of functionality.
def my_decorator(func):
    def wrapper():
        print("Before the fucntion called")
        func()
        print("After the functino is called")
    return wrapper

@my_decorator
def say_hello():
    print("Hello")
ß
say_hello()
# Out:
# Before the fucntion called
# Hello
# After the functino is called

# %%
#Decorator with arguments
def my_decorator(func):
    def wrapper(*args,**kwargs):
        print("Before the function call")
        result=func(*args,**kwargs)
        print("After function call")
        return result
    return wrapper

@my_decorator
def my_name_with_arg(name):
    print(f"Hello, {name}")

my_name_with_arg("Chandra")
# Out:
# Before the function call
# Hello, Chandra
# After function call

# %%
#Decorators can also be applied to classes in Python, not just functions. A class decorator is a function that takes a class as input and returns a modified (or wrapped) class.
def add_greet_method(cls):
    def greet(self):
        print(f"Hello from {self.name}!")
    cls.greet = greet
    return cls

@add_greet_method
class Person:
    def __init__(self, name):
        self.name = name

#Here greet method has been added to the Class Personß

p=Person("Chandra")
p.greet()
# Out:
# Hello from Chandra!

# %%
from dataclasses import dataclass
@dataclass
class Person():
    name: str
    age:int
    city:str

person=Person(name="Chandra",age="26",city="US")
print(person) 
#it does automatic type casting
# Out:
# Person(name='Chandra', age='26', city='US')

# %%
#Lets validate by using user defined functins

class Person():
    def __init__(self,name,age,city):
        if not isinstance(name,str):
            raise TypeError ("Name must be integer")
        if not isinstance(age, int):
            raise TypeError("Age must be number")
        if not isinstance(city, str):
            raise TypeError("Age must be number")
        self.name = name
        self.age = age
        self.city = city
    def __str__(self):
        return f"Person(name={self.name}, age={self.age}, city={self.city})"

# %%
p=Person("Chandra", 30,"Nuremberg")    
print(p)
# Out:
# Person(name=Chandra, age=30, city=Nuremberg)

# %%
p = Person("Chandra", "30","Nuremberg")    
print(p)
#It just raised the exception not much details
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 p = Person("Chandra", "30","Nuremberg")
#       2 print(p)
#
# Cell In[27], line 8, in Person.__init__(self, name, age, city)
#       6     raise TypeError ("Name must be integer")
#       7 if not isinstance(age, int):
# ----> 8     raise TypeError("Age must be number")
#       9 if not isinstance(city, str):
#      10     raise TypeError("Age must be number")
#
# TypeError: Age must be number

# %%
from pydantic import BaseModel
class Person(BaseModel):
    name: str
    age: int
    city: str

# %%
person=Person(name="Chandra",age="26",city="US")
print(person)
# Out:
# name='Chandra' age=26 city='US'

# %%
person=Person(name="Chandra",age=26,city="US")
print(person)
# Out:
# name='Chandra' age=26 city='US'

# %%
person=Person(name="Chandra",age=26,city=1234)
print(person)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 person=Person(name="Chandra",age=26,city=1234)
#       2 print(person)
#
# File ~/Courses/DataScience/NLP/AgenticAI/venvagentic/lib/python3.13/site-packages/pydantic/main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
# ...

# %%
from typing import List

class Classroom(BaseModel):
    subject: str
    stundent_name: List[str]
    total_count: int

# %%
clsrm=Classroom(subject='Maths',stundent_name=['chandra','raja','ankitha'],total_count=3)
print(clsrm)
# Out:
# subject='Maths' stundent_name=['chandra', 'raja', 'ankitha'] total_count=3

# %%
clsrm=Classroom(subject='Maths',stundent_name=['chandra',123,'ankitha'],total_count=3)
print(clsrm)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 clsrm=Classroom(subject='Maths',stundent_name=['chandra',123,'ankitha'],total_count=3)
#       2 print(clsrm)
#
# File ~/Courses/DataScience/NLP/AgenticAI/venvagentic/lib/python3.13/site-packages/pydantic/main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
# ...

# %% [markdown]
# #### 4. Model with Nested Models
# Create complex structures with nested models and Default, constraights etc

# %%
from pydantic import BaseModel,Field
from typing import Optional

# %%
class Address(BaseModel):
    dr_num:int
    strt: str
    zip: int

# %%
class Customer(BaseModel):
    cust_id:int=Field(le=9999,gt=0)
    name: str
    email_id:str=Field(default_factory=lambda: "user@domain.com", description='mandatory email address')
    mobile: Optional[int]=None
    telephne: int=Field(default=None)
    address: Address #<- Nested class

# %%
cust=Customer(cust_id=1,name='chandra',email_id='chandra@gmail.com',address={"dr_num":12,"strt":'Schwabstr',"zip":90763})

# %%
print(cust)
# Out:
# cust_id=1 name='chandra' email_id='chandra@gmail.com' mobile=None telephne=None address=Address(dr_num=12, strt='Schwabstr', zip=90763)
